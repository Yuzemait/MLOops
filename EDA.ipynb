# %%
import pandas as pd

df = pd.read_csv('./data/credit_train.csv')

print("Primeras filas del dataset:")
print(df.head())

print("\nEstadísticas descriptivas:")
print(df.describe())
# Out:
# Primeras filas del dataset:
#        X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...    X15    X16    X17  \
# 0   20000   2   2   2  44   0   0   0   0    0  ...  18503  17231  15410
# 1  100000   2   2   1  49   0  -1  -1  -1    0  ...  29628  13252   3723
# 2  210000   2   2   1  29   0   0   0   0    0  ...  41704  40509  41305
# 3  120000   2   2   2  28  -1   2   2  -2   -2  ...      0      0      0
# 4   50000   2   2   2  47   0   0   0   0    0  ...  50497  50544  50555
#
#     X18    X19    X20   X21   X22   X23  Y
# 0  2000   2000   2000  1100  1586   506  0
# 1  5325   5423  29628     0     0  3513  0
# 2  2000  20020   1672  1600  1600  2000  0
# 3     0      0      0     0     0     0  1
# 4  2200   5300   2000  2000  2000  2000  1
#
# [5 rows x 24 columns]
#
# Estadísticas descriptivas:
#                   X1            X2            X3            X4            X5  \
# count    25000.00000  25000.000000  25000.000000  25000.000000  25000.000000
# mean    168214.08000      1.603280      1.854080      1.549720     35.531760
# std     129973.93392      0.489227      0.792977      0.521631      9.235345
# min      10000.00000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.00000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.00000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.00000      2.000000      2.000000      2.000000     42.000000
# max    1000000.00000      2.000000      6.000000      3.000000     79.000000
#
#                  X6            X7           X8            X9           X10  \
# count  25000.000000  25000.000000  25000.00000  25000.000000  25000.000000
# mean      -0.017800     -0.133200     -0.16696     -0.219400     -0.268320
# std        1.117217      1.192139      1.19329      1.166001      1.129414
# min       -2.000000     -2.000000     -2.00000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.00000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.00000      0.000000      0.000000
# 75%        0.000000      0.000000      0.00000      0.000000      0.000000
# max        8.000000      8.000000      8.00000      8.000000      8.000000
#
#        ...            X15            X16            X17            X18  \
# count  ...   25000.000000   25000.000000   25000.000000   25000.000000
# mean   ...   43585.909520   40619.437840   39201.227680    5658.265680
# std    ...   64795.555721   61268.006291   60019.582934   16611.772332
# min    ...  -81334.000000  -61372.000000 -150953.000000       0.000000
# 25%    ...    2342.000000    1759.000000    1269.000000    1000.000000
# 50%    ...   19039.000000   18092.500000   17111.500000    2114.000000
# 75%    ...   54679.750000   50296.750000   49350.250000    5010.250000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#                 X19            X20           X21            X22  \
# count  2.500000e+04   25000.000000   25000.00000   25000.000000
# mean   6.041426e+03    5303.962760    4847.57568    4764.841400
# std    2.431938e+04   18352.753242   15823.03848   15106.172181
# min    0.000000e+00       0.000000       0.00000       0.000000
# 25%    8.700000e+02     392.750000     300.00000     264.000000
# 50%    2.013000e+03    1800.000000    1500.00000    1500.000000
# 75%    5.000000e+03    4552.000000    4056.00000    4087.000000
# max    1.684259e+06  896040.000000  621000.00000  426529.000000
#
#                  X23             Y
# count   25000.000000  25000.000000
# mean     5173.450600      0.221280
# std     17232.673013      0.415117
# min         0.000000      0.000000
# 25%       129.750000      0.000000
# 50%      1500.000000      0.000000
# 75%      4001.500000      0.000000
# max    528666.000000      1.000000
#
# [8 rows x 24 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Distribución de la variable objetivo (Y)
plt.figure(figsize=(6,4))
sns.countplot(x='Y', data=df)
plt.title('Distribución de la Variable Objetivo (Y)')
plt.show()

# %%
# Histograma para todas las características numéricas
df.hist(figsize=(14,10), bins=30)
plt.tight_layout()
plt.show()

# %%
# Mapa de calor para la correlación entre características
plt.figure(figsize=(12,8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Mapa de calor de la correlación entre variables')
plt.show()
